# %%
# %load_ext autoreload
# %autoreload 2
from imodelsx import explain_dataset_iprompt, get_add_two_numbers_dataset

# get a simple dataset of adding two numbers
input_strings, output_strings = get_add_two_numbers_dataset(num_examples=100)
for i in range(5):
    print(repr(input_strings[i]), repr(output_strings[i]))
# Out:
# 'Given the input numbers 7 and 7, the answer is' ' 14.\n\n'
# 'Given the input numbers 9 and 1, the answer is' ' 10.\n\n'
# 'Given the input numbers 2 and 6, the answer is' ' 8.\n\n'
# 'Given the input numbers 0 and 3, the answer is' ' 3.\n\n'
# 'Given the input numbers 1 and 5, the answer is' ' 6.\n\n'

# %%
# explain the relationship between the inputs and outputs
# with a natural-language prompt string
prompts, metadata = explain_dataset_iprompt(
    input_strings=input_strings,
    output_strings=output_strings,
    checkpoint='EleutherAI/gpt-j-6B', # which language model to use
    num_learned_tokens=3, # how long of a prompt to learn
    n_shots=3, # shots per example

    n_epochs=15, # how many epochs to search
    max_n_datapoints=1000, # limit to using this many datapoints in search
    verbose=0, # how much to print
    llm_float16=True, # whether to load the model in float_16
)
# Out:
# loading model...
# Training with 19 possible answers / random acc 5.3% / majority acc 10.4%
#   0%|          | 0/16 [00:00<?, ?it/s]
# population_pool: [' A user types', ' The problem with', ' [Click on', ' How are these', ' When I was', ' Given you have', ' When I was', ' How are these', ' A user types', ' A user types', ' A user types', ' The problem with']
# Loss = 2.843:   6%|▋         | 1/16 [00:11<02:51, 11.41s/it]
# population_pool: [' (Write code', ' (Write code', ' A simple function', ' Given an integer', ' [Input]:', ' [Input]:', ' The Input Numbers', ' The Input Numbers', ' How to use', ' When it says', ' What does it', ' What does it']
# Loss = 2.773:  12%|█▎        | 2/16 [00:21<02:32, 10.93s/it]
# population_pool: [' Write a method', ' Given an integer', ' A simple function', ' (Write code', ' Read a number', ' Find a number', '  Write a', ' Add another row', ' given two integers', ' [Input]:', ' 2> Input', ' write a program']
# Loss = 2.692:  19%|█▉        | 3/16 [00:32<02:20, 10.77s/it]
# population_pool: [' Write a method', ' A simple function', ' (Write code', ' Read a number', ' Given an integer', '  Write a', ' Find a number', ' write a method', ' Add another row', ' given two integers', ' [Input]:', ' You are given']
# Loss = 1.252:  25%|██▌       | 4/16 [00:43<02:08, 10.74s/it]
# population_pool: [' Add two integers', ' Write a method', ' (Write code', ' Read a number', ' A simple function', '  Write a', ' Given an integer', ' Find a number', ' given two integers', ' write a method', ' [Input]:', ' You are given']
# Loss = 1.280:  31%|███▏      | 5/16 [00:54<01:58, 10.74s/it]
# population_pool: [' Add two integers', ' Write a method', ' (Write code', ' Read a number', ' A simple function', ' Input an integer', ' Given an integer', '  Write a', ' Find a number', ' given two integers', ' write a method', ' [Input]:']
# Loss = 2.871:  38%|███▊      | 6/16 [01:04<01:47, 10.74s/it]
# population_pool: [' Add two integers', ' Write a method', ' (Write code', ' Read a number', ' A simple function', ' Given an integer', ' Input an integer', '  Write a', ' Find a number', ' Enter each integer', ' "Input data', ' given two integers']
# Loss = 2.871:  38%|███▊      | 6/16 [01:12<02:01, 12.14s/it]
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /tmp/ipykernel_2752248/1301869516.py:3 in <module>                                               │
# │                                                                                                  │
# │ [Errno 2] No such file or directory: '/tmp/ipykernel_2752248/1301869516.py'                      │
# │                                                                                                  │
# │ /home/chansingh/imodelsX/imodelsx/iprompt/api.py:433 in explain_dataset_iprompt                  │
# │                                                                                                  │
# │   430 │   np.random.seed(seed)                                                                   │
# │   431 │   torch.manual_seed(seed)                                                                │
# │   432 │   random.seed(seed)                                                                      │
# │ ❱ 433 │   r = defaultdict(list)                                                                  │
# │   434 │   r = train_model(                                                                       │
# │   435 │   │   r=r,                                                                               │
# │   436 │   │   input_strs=input_strings,                                                          │
# │                                                                                                  │
# │ /home/chansingh/imodelsX/imodelsx/iprompt/api.py:170 in train_model                              │
# │                                                                                                  │
# │   167 │   │   │   x_tokenized = tok(x_text).to(device)                                           │
# │   168 │   │   │   y_tokenized = tok(y_text).to(device)                                           │
# │   169 │   │   │   full_text_tokenized = tok(batch['text']).to(device)                            │
# │ ❱ 170 │   │   │                                                                                  │
# │   171 │   │   │   loss, n_correct = model.compute_loss_and_call_backward(                        │
# │   172 │   │   │   │   x_tokenized=x_tokenized,                                                   │
# │   173 │   │   │   │   y_tokenized=y_tokenized,                                                   │
# │                                                                                                  │
# │ /home/chansingh/imodelsX/imodelsx/iprompt/ipromptx.py:337 in compute_loss_and_call_backward      │
# │                                                                                                  │
# │   334 │   │   │   (population_input_ids, mutated_population_input_ids), dim=0                    │
# │   335 │   │   )                                                                                  │
# │   336 │   │   # Re-score new guys                                                                │
# │ ❱ 337 │   │   all_candidate_losses, all_candidate_n_correct = self._score_population(            │
# │   338 │   │   │   x_tokenized=x_tokenized,                                                       │
# │   339 │   │   │   y_tokenized=y_tokenized,                                                       │
# │   340 │   │   │   population_input_ids=full_population_input_ids,                                │
# │                                                                                                  │
# │ /home/chansingh/imodelsX/imodelsx/iprompt/ipromptx.py:264 in _score_population                   │
# │                                                                                                  │
# │   261 │   │   for i in range(pop_size):                                                          │
# │   262 │   │   │   with torch.no_grad():                                                          │
# │   263 │   │   │   │   _cand_input_ids, cand_loss, cand_n_correct = (                             │
# │ ❱ 264 │   │   │   │   │   self._compute_loss_with_set_prefix(                                    │
# │   265 │   │   │   │   │   │   original_input_ids=x_tokenized.input_ids,                          │
# │   266 │   │   │   │   │   │   next_token_ids=y_tokenized.input_ids,                              │
# │   267 │   │   │   │   │   │   possible_answer_mask=possible_answer_mask,                         │
# │                                                                                                  │
# │ /home/chansingh/imodelsX/imodelsx/iprompt/utils.py:297 in _compute_loss_with_set_prefix          │
# │                                                                                                  │
# │   294 │   │   assert input_ids.shape == (original_input_ids.shape[0], original_input_ids.shape   │
# │   295 │   │                                                                                      │
# │   296 │   │   # feed into the model. prefix-handling is implemented in PrefixModel::forward.     │
# │ ❱ 297 │   │   full_input_ids, outputs = self.forward(                                            │
# │   298 │   │   │   input_ids=input_ids,                                                           │
# │   299 │   │   │   prefix_ids=prefix_ids,                                                         │
# │   300 │   │   )                                                                                  │
# │                                                                                                  │
# │ /home/chansingh/imodelsX/imodelsx/iprompt/utils.py:230 in forward                                │
# │                                                                                                  │
# │   227 │   │   attention_mask = ~(new_input_ids == self.tokenizer.pad_token_id)                   │
# │   228 │   │                                                                                      │
# │   229 │   │   assert new_input_ids.shape == embeddings.shape[0:2]                                │
# │ ❱ 230 │   │   return new_input_ids, self.model(                                                  │
# │   231 │   │   │   inputs_embeds=embeddings,                                                      │
# │   232 │   │   │   attention_mask=attention_mask,                                                 │
# │   233 │   │   )                                                                                  │
# │                                                                                                  │
# │ /home/chansingh/.embgam/lib/python3.8/site-packages/torch/nn/modules/module.py:1130 in           │
# │ _call_impl                                                                                       │
# │                                                                                                  │
# │   1127 │   │   # this function, and just call forward.                                           │
# │   1128 │   │   if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks o  │
# │   1129 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1130 │   │   │   return forward_call(*input, **kwargs)                                         │
# │   1131 │   │   # Do not call functions when jit is used                                          │
# │   1132 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1133 │   │   if self._backward_hooks or _global_backward_hooks:                                │
# │                                                                                                  │
# │ /home/chansingh/.embgam/lib/python3.8/site-packages/transformers/models/gptj/modeling_gptj.py:82 │
# │ 1 in forward                                                                                     │
# │                                                                                                  │
# │    818 │   │   """                                                                               │
# │    819 │   │   return_dict = return_dict if return_dict is not None else self.config.use_return  │
# │    820 │   │                                                                                     │
# │ ❱  821 │   │   transformer_outputs = self.transformer(                                           │
# │    822 │   │   │   input_ids,                                                                    │
# │    823 │   │   │   past_key_values=past_key_values,                                              │
# │    824 │   │   │   attention_mask=attention_mask,                                                │
# │                                                                                                  │
# │ /home/chansingh/.embgam/lib/python3.8/site-packages/torch/nn/modules/module.py:1130 in           │
# │ _call_impl                                                                                       │
# │                                                                                                  │
# │   1127 │   │   # this function, and just call forward.                                           │
# │   1128 │   │   if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks o  │
# │   1129 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1130 │   │   │   return forward_call(*input, **kwargs)                                         │
# │   1131 │   │   # Do not call functions when jit is used                                          │
# │   1132 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1133 │   │   if self._backward_hooks or _global_backward_hooks:                                │
# │                                                                                                  │
# │ /home/chansingh/.embgam/lib/python3.8/site-packages/transformers/models/gptj/modeling_gptj.py:67 │
# │ 6 in forward                                                                                     │
# │                                                                                                  │
# │    673 │   │   │   │   │   head_mask[i],                                                         │
# │    674 │   │   │   │   )                                                                         │
# │    675 │   │   │   else:                                                                         │
# │ ❱  676 │   │   │   │   outputs = block(                                                          │
# │    677 │   │   │   │   │   hidden_states,                                                        │
# │    678 │   │   │   │   │   layer_past=layer_past,                                                │
# │    679 │   │   │   │   │   attention_mask=attention_mask,                                        │
# │                                                                                                  │
# │ /home/chansingh/.embgam/lib/python3.8/site-packages/torch/nn/modules/module.py:1130 in           │
# │ _call_impl                                                                                       │
# │                                                                                                  │
# │   1127 │   │   # this function, and just call forward.                                           │
# │   1128 │   │   if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks o  │
# │   1129 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1130 │   │   │   return forward_call(*input, **kwargs)                                         │
# │   1131 │   │   # Do not call functions when jit is used                                          │
# │   1132 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1133 │   │   if self._backward_hooks or _global_backward_hooks:                                │
# │                                                                                                  │
# │ /home/chansingh/.embgam/lib/python3.8/site-packages/transformers/models/gptj/modeling_gptj.py:31 │
# │ 0 in forward                                                                                     │
# │                                                                                                  │
# │    307 │   ) -> Union[Tuple[torch.Tensor], Optional[Tuple[torch.Tensor, Tuple[torch.FloatTensor  │
# │    308 │   │   residual = hidden_states                                                          │
# │    309 │   │   hidden_states = self.ln_1(hidden_states)                                          │
# │ ❱  310 │   │   attn_outputs = self.attn(                                                         │
# │    311 │   │   │   hidden_states,                                                                │
# │    312 │   │   │   layer_past=layer_past,                                                        │
# │    313 │   │   │   attention_mask=attention_mask,                                                │
# │                                                                                                  │
# │ /home/chansingh/.embgam/lib/python3.8/site-packages/torch/nn/modules/module.py:1130 in           │
# │ _call_impl                                                                                       │
# │                                                                                                  │
# │   1127 │   │   # this function, and just call forward.                                           │
# │   1128 │   │   if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks o  │
# │   1129 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1130 │   │   │   return forward_call(*input, **kwargs)                                         │
# │   1131 │   │   # Do not call functions when jit is used                                          │
# │   1132 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1133 │   │   if self._backward_hooks or _global_backward_hooks:                                │
# │                                                                                                  │
# │ /home/chansingh/.embgam/lib/python3.8/site-packages/transformers/models/gptj/modeling_gptj.py:23 │
# │ 3 in forward                                                                                     │
# │                                                                                                  │
# │    230 │   │   │   q_rot = query[:, :, :, : self.rotary_dim]                                     │
# │    231 │   │   │   q_pass = query[:, :, :, self.rotary_dim :]                                    │
# │    232 │   │   │                                                                                 │
# │ ❱  233 │   │   │   sincos = fixed_pos_embedding(k_rot, 1, seq_len=seq_len)                       │
# │    234 │   │   │   k_rot = apply_rotary_pos_emb(k_rot, sincos, offset=offset)                    │
# │    235 │   │   │   q_rot = apply_rotary_pos_emb(q_rot, sincos, offset=offset)                    │
# │    236                                                                                           │
# │                                                                                                  │
# │ /home/chansingh/.embgam/lib/python3.8/site-packages/transformers/models/gptj/modeling_gptj.py:64 │
# │ in fixed_pos_embedding                                                                           │
# │                                                                                                  │
# │     61 │   │   seq_len = x.shape[seq_dim]                                                        │
# │     62 │   inv_freq = 1.0 / (10000 ** (torch.arange(0, dim, 2) / dim))                           │
# │     63 │   sinusoid_inp = (                                                                      │
# │ ❱   64 │   │   torch.einsum("i , j -> i j", torch.arange(seq_len, dtype=torch.float), inv_freq)  │
# │     65 │   )                                                                                     │
# │     66 │   return torch.sin(sinusoid_inp), torch.cos(sinusoid_inp)                               │
# │     67                                                                                           │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# KeyboardInterrupt
