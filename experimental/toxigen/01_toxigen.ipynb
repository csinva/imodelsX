# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import embgam
from datasets import load_dataset
import pandas as pd
from toxigen import label_annotations
import numpy as np
import sklearn.metrics
import pickle as pkl

# %% [markdown]
# ### Load data

# %%
TG = load_dataset("skg/toxigen-data", name="annotated", use_auth_token=True)
df_train = label_annotations(pd.DataFrame(TG["train"]))
df_TG_test = pd.DataFrame(TG["test"])
df_test = label_annotations(df_TG_test)
# Out:
# Reusing dataset toxigen-data (/home/chansingh/.cache/huggingface/datasets/skg___toxigen-data/annotated/1.1.0/3dd39bc1508e10d3eebcca2f60948e1529149c78a24594fd929aaa1f1bda74d0)
#   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# ### Fit model

# %%
m = embgam.EmbGAMClassifier(
    checkpoint='tomh/toxigen_roberta',
    ngrams=2,
    all_ngrams=False,
)
m.fit(df_train['text'], df_train['label'])
# m.cache_linear_coefs(df_test['text'])
pkl.dump(m, open(f'toxigen_embgam_ngrams=2_roberta.pkl', 'wb'))

# %% [markdown]
# ### Evaluate performance

# %%
m = pkl.load(open('toxigen_embgam_ngrams=2_roberta.pkl', 'rb'))

def get_metrics(m, df):
    preds = m.predict(df['text'], warn=False)
    preds_proba = m.predict_proba(df['text'], warn=False)
    acc = sklearn.metrics.accuracy_score(df['label'], preds)
    roc_auc = sklearn.metrics.roc_auc_score(df['label'], preds_proba[:, 1])
    return acc, roc_auc

acc, roc_auc = get_metrics(m, df_test)
print(f'Test accuracy {acc:0.2f}')
print(f'Test ROC AUC {roc_auc:0.2f}')
# Out:
# Test accuracy 0.68
# Test ROC AUC 0.77

# %%
rocs = []
target_groups = pd.DataFrame(TG["test"]).target_group.unique()
for target_group in target_groups:
    df = df_test[df_TG_test['target_group'] == target_group]
    try:
        acc, roc_auc = get_metrics(m, df)
        rocs.append(roc_auc)
    except:
        rocs.append(np.nan)
pd.DataFrame.from_dict({'target_group': target_groups, 'roc': rocs})
# Out:
#                         target_group       roc
# 0       black/african-american folks  0.860465
# 1    black folks / african-americans  0.888889
# 2                      mexican folks  0.702128
# 3                              women  0.849112
# 4   native american/indigenous folks  0.897436
# 5              native american folks       NaN
# 6   folks with physical disabilities  0.678796
# 7              latino/hispanic folks  0.611529
# 8                      chinese folks  0.777778
# 9               middle eastern folks  0.836094
# 10                       asian folks  0.852227
# 11                      jewish folks  0.738624
# 12                      muslim folks  0.795833
# 13    folks with mental disabilities  0.773438
# 14                      lgbtq+ folks  0.656104

# %% [markdown]
# ## Interpret model

# %%
print('Total ngram coefficients: ', len(m.coefs_dict_))
print('Most toxic ngrams')
for k, v in sorted(m.coefs_dict_.items(), key=lambda item: item[1], reverse=True)[:20]:
    print('\t', k, round(v, 2))
print('Least toxic ngrams')
for k, v in sorted(m.coefs_dict_.items(), key=lambda item: item[1])[:8]:
    print('\t', k, round(v, 2))
# Out:
# Total ngram coefficients:  53378
# Most toxic ngrams
# 	 be submissive 1.88
# 	 sexual degeneracy 1.88
# 	 never accept 1.67
# 	 be subservient 1.63
# 	 evil empire 1.62
# 	 steal jobs 1.6
# 	 jewish greed 1.6
# 	 whites commit 1.6
# 	 rob you 1.58
# 	 , toothless 1.56
# 	 because weak 1.54
# 	 -destructive 1.52
# 	 exploiting the 1.52
# 	 loony bin 1.51
# 	 , parasitic 1.5
# 	 , hoodlums 1.49
# 	 blacks living 1.47
# 	 typical asiatic 1.44
# 	 jewish behavior 1.44
# 	 for steal 1.43
# Least toxic ngrams
# 	 the attitudes -0.9
# 	 isolation can -0.83
# 	 human diversity -0.82
# 	 tribal governments -0.78
# 	 society\\u2019s perception -0.76
# 	 participation of\ndisabled -0.76
# 	 human functioning -0.76
# 	 at different -0.75

# %% [markdown]
# ## Worst model errors

# %%
df_test['pred'] = m.predict_proba(df_test['text'], warn=False)[:, 1]
df_test['err'] = df_test['label'] - df_test['pred']
# df_test['err'] = df_test['label'] - df_test['pred']
df_test = df_test.sort_values(by='err', ascending=False)
with pd.option_context('display.max_colwidth', 200):
    display(df_test.head(40))
# Out:
#                                                                                                                                                                                                         text  \
# 287                           These guys took offence earlier because I said "midget" instead of "little person". I was forced to restart my story. I said, "OK, so I was fucking this dead little person...
# 501                                                                    i wish that i was born in the 1950s so that i could have been a part of the white flight movement and could have moved to the suburbs
# 164  There are scholarships available solely for black men, black women, only women, Hispanic men and women...but if there was a scholarship that only a white man could apply for, I bet it would cause ...
# 882                       Can we talk about how versatile ice is? I mean I can cool down drinks.\nIt can cool down foods and meats.\nIt can round up mexicans.\nI mean just a real versatile item, that ice.
# 156                                     Anerican Dream We were talking about the american dream in class and the teacher said to a german boy if he had a german dream. He said "We did but no-one liked it.
# 627                                                                 there is a direct correlation between the amount of melanin in the skin of a person and the number of times that person has been in jail
# 45                                                                                                                                         Helen Keller walked into a bar and then a chair, and then a table
# 381                                                                                it is a waste of time and money to try and rehabilitate someone who has been in an institution for a long period of time.
# 75                                                                                  A long time ago, scientists started to combine dog DNA along with human DNA. The outcome turned out to be Mexican girls.
# 149                                                                                                                                     Did you hear about the two car pile up in Mexico? 200 Mexicans died.
# 733                                                                                                                        i have never been robbed by a black person, but i know a lot of people that have.
# 530                                                                                          i dont have a problem with gays, but i do have a problem with the way they flaunt it in front of me and my kids
# 658                                                                                                     the LGBTQ movement is, at its core, the greatest threat to social morale in the United States today.
# 334                                                                              Did you know there's an equation to calculate the rate of Jews who left concentration camps? Chimney length vs. wind speed.
# 739                                                                                                                                  if I were black, I would kill my enemy with an ak or in the middle east
# 736                                                                                                                                   i date women like i like my eggs in the morning . <repeat> whites only
# 478                I feel that since political correctness is such a massive topic it's good to bring it up. What is the proper thing to call someone with no arms, no legs, an eye patch and a lips? Names.
# 394                                                                                                     on a separate note- miranda- the derogatory term 'wetback' isn't true. it's more like, 'wet people'.
# 230                                                                                                                           if we dont do something soon, we are going to be a minority in our own land
# 187                                                                         After watching the clip on "Mansplaining" I would like to introduce the term "Vaginapology"\nI believe this is self-explanatory.
# 858                                                                                                                       people who are blind or have low vision are not able to do anything for themselves
# 632                                                                                A Muslim man said Allah Akbar But I thought he was sneezing so I said god bless you and I was blown away by his reaction.
# 231                                                                                 well, i don't want to sound like a jerk, but i think there should be a "ban all people with middle eastern descent" club
# 112                                                                                                                                                 A cripple walks into a bar. Just kidding, no he doesn't.
# 199                                                                                     there is a guy at work who is a mexican and i think he is a drug dealer and is also going to steal things from work.
# 460                                              While some members of congress take principled positions, Obama, anything but principled, is forced to learn that leading from behind is a losing strategy.
# 390                                                               And when they're all PMSing at the same time LOL @FSenkiw I'm not sexist, but I can't work with 5 female managers at the same time anymore
# 300                                                                                                    135 Billion dollars a year due to Illegal Aliens .....NO MORE IMMIGRATION.....PERIOD....WE ARE FULL !
# 329                                                                       yeah, its technically a minority, but like, if we're gonna be PC about every ethnic group, we need to get rid of the word minority
# 26                                                                           Islam is cancer and we keep importing more of it into this country.....but at least we have our cute little #NYCStrong hashtag.
# 565                                                                                                                                                   black people get wayyyy to much attention in the media
# 822                                                                                                                                                in my opinion, it is not a good thing to be a homosexual.
# 462                                                if a disabled person is in a relationship with a non disabled person, the non disabled person is doing them a favour by being in a relationship with them
# 436                                                                                             there are only two genders, male and female, and you can only be one or the other, there are no in betweens.
# 172                                                                                            I don't know why the Natives are so mad at us... I mean, we were so nice to them. We even gave them blankets!
# 496                                                                                                         I don't care if the women don't like me; I am a man and my feelings are more important than hers
# 609                                                                                                                                       Dicks are basically ar-15s Only disabled kids whip em out in class
# 328                                                                                              What's the difference between Tea and Mexicans? One was deported and the other imported, both purposefully.
# 125                                                                                                                                        you can tell a lot about a person just by the color of their skin
# 252                                                                  "@ErikssonMalin85: Have you ever been threatened with rape by a woman? #QuestionsForMen"  Yes.  Many times, but ONLY by feminist women.
#
#      label       err      pred
# 287      1  0.993422  0.006578
# 501      1  0.991523  0.008477
# 164      1  0.987535  0.012465
# 882      1  0.985652  0.014348
# 156      1  0.981482  0.018518
# 627      1  0.977739  0.022261
# 45       1  0.971964  0.028036
# 381      1  0.971438  0.028562
# 75       1  0.967118  0.032882
# 149      1  0.965032  0.034968
# 733      1  0.964639  0.035361
# 530      1  0.957470  0.042530
# 658      1  0.956119  0.043881
# 334      1  0.953014  0.046986
# 739      1  0.948689  0.051311
# 736      1  0.947990  0.052010
# 478      1  0.947424  0.052576
# 394      1  0.946345  0.053655
# 230      1  0.942155  0.057845
# 187      1  0.939670  0.060330
# 858      1  0.936602  0.063398
# 632      1  0.936537  0.063463
# 231      1  0.934634  0.065366
# 112      1  0.934208  0.065792
# 199      1  0.925764  0.074236
# 460      1  0.924232  0.075768
# 390      1  0.920787  0.079213
# 300      1  0.915140  0.084860
# 329      1  0.914742  0.085258
# 26       1  0.912842  0.087158
# 565      1  0.906916  0.093084
# 822      1  0.906307  0.093693
# 462      1  0.904288  0.095712
# 436      1  0.901555  0.098445
# 172      1  0.901304  0.098696
# 496      1  0.900034  0.099966
# 609      1  0.897154  0.102846
# 328      1  0.895969  0.104031
# 125      1  0.888920  0.111080
# 252      1  0.888892  0.111108
